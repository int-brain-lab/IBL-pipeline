# %%
import datajoint as dj
import matplotlib.pyplot as plt
from ibl import reference, subject, acquisition, behavior, ephys
# Out:
# /usr/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /usr/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# Connecting root@db:3306

# %% [markdown]
# # References

# %%
(dj.ERD(reference) - 1)

# %%
(dj.ERD(reference) - 1).save('/images/reference_erd.png')

# %% [markdown]
# # Subject

# %%
(dj.ERD(subject) - 1)

# %%
(dj.ERD(subject) - 1).save('/images/subject_erd.png')

# %% [markdown]
# # Acquisition

# %%
(dj.ERD(acquisition) - 1)

# %%
(dj.ERD(acquisition) - 1).save('/images/acquisition_erd.png')

# %% [markdown]
# # Behavior

# %%
(dj.ERD(behavior) - 1)

# %%
(dj.ERD(behavior) - 1).save('/images/behavior_erd.png')

# %% [markdown]
# # Ephys

# %%
(dj.ERD(ephys) - 1)

# %%
(dj.ERD(ephys) - 1).save('/images/ephys_erd.png')

# %% [markdown]
# # All combined

# %%
all_erd = dj.ERD(subject) + dj.ERD(reference) + dj.ERD(acquisition) + dj.ERD(behavior) + dj.ERD(ephys)
all_erd

# %%
all_erd.save('/images/all_erd.png')
