# %%
import datajoint as dj
import matplotlib.pyplot as plt
import pygraphviz
import subject
import reference
import acquisition
# Out:
# Connecting shanshen@127.0.0.1:3306

# %%
f = dj.ERD(subject)

# %%
f = dj.ERD(subject.Allele) + 1 - 1
f.save('sequence-allele-line.png')

# %%
f = dj.ERD(subject) + dj.ERD(acquisition) + dj.ERD(reference)

# %%
f.save('subject_acquisition_reference_erd.png')

# %%
dj.ERD(subject)

# %%
dj.ERD(acquisition)
